# %% [markdown]
# <a href="https://colab.research.google.com/github/nuttnice187/crashes/blob/dev/Getting-Started.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Getting Started

# %%
# !git clone -b dev https://github.com/nuttnice187/crashes.git
# Out:
# Cloning into 'crashes'...
# remote: Enumerating objects: 520, done.
# remote: Counting objects: 100% (55/55), done.
# remote: Compressing objects: 100% (53/53), done.
# remote: Total 520 (delta 17), reused 3 (delta 1), pack-reused 465 (from 1)
# Receiving objects: 100% (520/520), 911.03 KiB | 11.25 MiB/s, done.
# Resolving deltas: 100% (217/217), done.

# %%
# !python crashes/entry.py --job data_capture --task ingestion
# Out:
# 2026-02-18 17:55:13,446 - __main__ - INFO - Namespace(job='data_capture', task='ingestion', api_url=None, source_path=None, target_path=None, run_id=None)
# 2026-02-18 17:55:13,447 - __main__ - INFO - Added 'crashes' to sys.path
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/02/18 17:55:20 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 2026-02-18 17:55:39,297 - __main__ - WARNING - Could not read existing Parquet data from /content/drive/MyDrive/crashes_data: [UNABLE_TO_INFER_SCHEMA] Unable to infer schema for Parquet. It must be specified manually. SQLSTATE: 42KD9. Proceeding without existing data.
# 2026-02-18 17:55:39,297 - __main__ - INFO - No existing data to join with, or existing data is empty. Loading all data from source.
# 26/02/18 17:55:40 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.

# %%
from pyspark.sql import DataFrame, SparkSession

spark = SparkSession.builder.getOrCreate()
post_load = spark.read.parquet('drive/MyDrive/crashes_data')

post_load.count()
# Out:
# 1000

# %%
post_load.printSchema()
# Out:
# root
#  |-- computed_region_rpca_8um6: string (nullable = true)
#  |-- alignment: string (nullable = true)
#  |-- beat_of_occurrence: string (nullable = true)
#  |-- crash_date: string (nullable = true)
#  |-- crash_day_of_week: string (nullable = true)
#  |-- crash_hour: string (nullable = true)
#  |-- crash_record_id: string (nullable = true)
#  |-- crash_type: string (nullable = true)
#  |-- damage: string (nullable = true)
#  |-- date_police_notified: string (nullable = true)
#  |-- device_condition: string (nullable = true)
#  |-- first_crash_type: string (nullable = true)
#  |-- injuries_fatal: string (nullable = true)
#  |-- injuries_incapacitating: string (nullable = true)
#  |-- injuries_no_indication: string (nullable = true)
#  |-- injuries_non_incapacitating: string (nullable = true)
#  |-- injuries_reported_not_evident: string (nullable = true)
#  |-- injuries_total: string (nullable = true)
#  |-- injuries_unknown: string (nullable = true)
#  |-- intersection_related_i: string (nullable = true)
#  |-- latitude: string (nullable = true)
#  |-- lighting_condition: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- longitude: string (nullable = true)
#  |-- most_severe_injury: string (nullable = true)
#  |-- num_units: string (nullable = true)
#  |-- posted_speed_limit: string (nullable = true)
#  |-- prim_contributory_cause: string (nullable = true)
#  |-- report_type: string (nullable = true)
#  |-- road_defect: string (nullable = true)
#  |-- roadway_surface_cond: string (nullable = true)
#  |-- sec_contributory_cause: string (nullable = true)
#  |-- street_direction: string (nullable = true)
#  |-- street_name: string (nullable = true)
#  |-- street_no: string (nullable = true)
#  |-- traffic_control_device: string (nullable = true)
#  |-- trafficway_type: string (nullable = true)
#  |-- weather_condition: string (nullable = true)
#  |-- statements_taken_i: string (nullable = true)
#  |-- hit_and_run_i: string (nullable = true)
#  |-- private_property_i: string (nullable = true)
#  |-- crash_date_est_i: string (nullable = true)
#  |-- photos_taken_i: string (nullable = true)
#  |-- work_zone_i: string (nullable = true)
#  |-- dooring_i: string (nullable = true)
#  |-- ingest_date: timestamp (nullable = true)
#  |-- crash_month: integer (nullable = true)
#  |-- crash_year: integer (nullable = true)

# %%
post_load.show()
# Out:
# +-------------------------+------------------+------------------+--------------------+-----------------+----------+--------------------+--------------------+-------------+--------------------+--------------------+--------------------+--------------+-----------------------+----------------------+---------------------------+-----------------------------+--------------+----------------+----------------------+-------------+------------------+--------------------+--------------+--------------------+---------+------------------+-----------------------+--------------------+-----------+--------------------+----------------------+----------------+----------------+---------+----------------------+--------------------+-----------------+------------------+-------------+------------------+----------------+--------------+-----------+---------+--------------------+-----------+----------+
# |computed_region_rpca_8um6|         alignment|beat_of_occurrence|          crash_date|crash_day_of_week|crash_hour|     crash_record_id|          crash_type|       damage|date_police_notified|    device_condition|    first_crash_type|injuries_fatal|injuries_incapacitating|injuries_no_indication|injuries_non_incapacitating|injuries_reported_not_evident|injuries_total|injuries_unknown|intersection_related_i|     latitude|lighting_condition|            location|     longitude|  most_severe_injury|num_units|posted_speed_limit|prim_contributory_cause|         report_type|road_defect|roadway_surface_cond|sec_contributory_cause|street_direction|     street_name|street_no|traffic_control_device|     trafficway_type|weather_condition|statements_taken_i|hit_and_run_i|private_property_i|crash_date_est_i|photos_taken_i|work_zone_i|dooring_i|         ingest_date|crash_month|crash_year|
# +-------------------------+------------------+------------------+--------------------+-----------------+----------+--------------------+--------------------+-------------+--------------------+--------------------+--------------------+--------------+-----------------------+----------------------+---------------------------+-----------------------------+--------------+----------------+----------------------+-------------+------------------+--------------------+--------------+--------------------+---------+------------------+-----------------------+--------------------+-----------+--------------------+----------------------+----------------+----------------+---------+----------------------+--------------------+-----------------+------------------+-------------+------------------+----------------+--------------+-----------+---------+--------------------+-----------+----------+
# |                       12|STRAIGHT AND LEVEL|              2412|2026-02-15T13:25:...|                1|        13|77a0dabcb38b4d65a...|NO INJURY / DRIVE...|$501 - $1,500|2026-02-15T13:26:...|         NO CONTROLS|SIDESWIPE SAME DI...|             0|                      0|                     2|                          0|                            0|             0|               0|                  NULL|41.9995264608|          DAYLIGHT|{"type": "Point",...| -87.684408446|NO INDICATION OF ...|        2|                20|   FAILING TO REDUCE...|            ON SCENE| NO DEFECTS|                 DRY|  FOLLOWING TOO CLO...|               W|      ARTHUR AVE|     2145|     STOP SIGN/FLASHER|             ONE-WAY|            CLEAR|              NULL|         NULL|              NULL|            NULL|          NULL|       NULL|     NULL|2026-02-18 17:55:...|          2|      2026|
# |                       30|STRAIGHT AND LEVEL|              1133|2026-02-15T13:20:...|                1|        13|852fec7ce9a357a06...|NO INJURY / DRIVE...|  OVER $1,500|2026-02-15T13:45:...|             UNKNOWN|SIDESWIPE SAME DI...|             0|                      0|                     2|                          0|                            0|             0|               0|                  NULL|41.8743560735|          DAYLIGHT|{"type": "Point",...|-87.7192288721|NO INDICATION OF ...|        2|                25|    IMPROPER LANE USAGE|NOT ON SCENE (DES...|    UNKNOWN|                 DRY|   UNABLE TO DETERMINE|               W|   CONGRESS PKWY|     3729|        TRAFFIC SIGNAL|         NOT DIVIDED|            CLEAR|              NULL|            Y|              NULL|            NULL|          NULL|       NULL|     NULL|2026-02-18 17:55:...|          2|      2026|
# |                       48|STRAIGHT AND LEVEL|              1712|2026-02-15T13:15:...|                1|        13|66c3bfb0cecfa8a9d...|NO INJURY / DRIVE...|$501 - $1,500|2026-02-15T14:00:...|         NO CONTROLS|               ANGLE|             0|                      0|                     2|                          0|                            0|             0|               0|                  NULL|41.9694592415|          DAYLIGHT|{"type": "Point",...|-87.7282108954|NO INDICATION OF ...|        2|                30|    UNABLE TO DETERMINE|NOT ON SCENE (DES...| NO DEFECTS|                 DRY|   UNABLE TO DETERMINE|               N|      PULASKI RD|     4840|           NO CONTROLS|         PARKING LOT|            CLEAR|              NULL|         NULL|                 N|            NULL|          NULL|       NULL|     NULL|2026-02-18 17:55:...|          2|      2026|
# |                       21|STRAIGHT AND LEVEL|              2521|2026-02-15T13:15:...|                1|        13|a1afc90764f87ff30...|NO INJURY / DRIVE...|  OVER $1,500|2026-02-15T13:50:...|         NO CONTROLS|            REAR END|             0|                      0|                     2|                          0|                            0|             0|               0|                  NULL| 41.935692629|          DAYLIGHT|{"type": "Point",...|-87.7469082863|NO INDICATION OF ...|        2|                30|    UNABLE TO DETERMINE|NOT ON SCENE (DES...|    UNKNOWN|                 DRY|        NOT APPLICABLE|               N|      CICERO AVE|     3016|           NO CONTROLS|DIVIDED - W/MEDIA...|            CLEAR|              NULL|         NULL|              NULL|            NULL|          NULL|       NULL|     NULL|2026-02-18 17:55:...|          2|      2026|
# |                       30|STRAIGHT AND LEVEL|              1123|2026-02-15T13:09:...|                1|        13|78b4d81b49a358c38...|NO INJURY / DRIVE...|  OVER $1,500|2026-02-15T13:09:...|FUNCTIONING PROPERLY|            REAR END|             0|                      0|                     2|                          0|                            0|             0|               0|                  NULL|41.8829039762|          DAYLIGHT|{"type": "Point",...| -87.706319802|NO INDICATION OF ...|        2|                30|    IMPROPER LANE USAGE|NOT ON SCENE (DES...|    UNKNOWN|             UNKNOWN|        NOT APPLICABLE|               N|      KEDZIE AVE|      102|        TRAFFIC SIGNAL|         NOT DIVIDED|            CLEAR|              NULL|         NULL|              NULL|            NULL|          NULL|       NULL|     NULL|2026-02-18 17:55:...|          2|      2026|
# |                       53|STRAIGHT AND LEVEL|              1915|2026-02-15T13:08:...|                1|        13|147858e1a4ec177d2...|NO INJURY / DRIVE...|  OVER $1,500|2026-02-15T13:09:...|FUNCTIONING PROPERLY|SIDESWIPE SAME DI...|             0|                      0|                     2|                          0|                            0|             0|               0|                  NULL|41.9616712617|          DAYLIGHT|{"type": "Point",...|-87.6546237757|NO INDICATION OF ...|        2|                30|    UNABLE TO DETERMINE|            ON SCENE| NO DEFECTS|                 DRY|        NOT APPLICABLE|               W|    MONTROSE AVE|      997|        TRAFFIC SIGNAL|         NOT DIVIDED|            CLEAR|              NULL|            Y|              NULL|            NULL|          NULL|       NULL|     NULL|2026-02-18 17:55:...|          2|      2026|
# |                       21|STRAIGHT AND LEVEL|              1731|2026-02-15T13:00:...|                1|        13|79c8d396377e18e96...|INJURY AND / OR T...|  OVER $1,500|2026-02-15T18:00:...|         NO CONTROLS|            REAR END|             0|                      0|                     2|                          0|                            1|             1|               0|                  NULL|41.9452385534|          DAYLIGHT|{"type": "Point",...|-87.7468918112|REPORTED, NOT EVI...|        2|                30|    UNABLE TO DETERMINE|NOT ON SCENE (DES...|    UNKNOWN|                 DRY|        NOT APPLICABLE|               N|      CICERO AVE|     3519|           NO CONTROLS|DIVIDED - W/MEDIA...|            CLEAR|              NULL|         NULL|              NULL|            NULL|          NULL|       NULL|     NULL|2026-02-18 17:55:...|          2|      2026|
# |                       28|STRAIGHT AND LEVEL|              1134|2026-02-15T13:00:...|                1|        13|e2c0b45a618cfce32...|NO INJURY / DRIVE...|$501 - $1,500|2026-02-15T13:35:...|         NO CONTROLS|PARKED MOTOR VEHICLE|             0|                      0|                     2|                          0|                            0|             0|               0|                  NULL|41.8672098515|          DAYLIGHT|{"type": "Point",...|-87.7046164403|NO INDICATION OF ...|        3|                30|         NOT APPLICABLE|            ON SCENE| NO DEFECTS|                 DRY|        NOT APPLICABLE|               S|         TROY ST|     1132|           NO CONTROLS|             ONE-WAY|            CLEAR|              NULL|            Y|                 N|               N|          NULL|       NULL|     NULL|2026-02-18 17:55:...|          2|      2026|
# |                       33|STRAIGHT AND LEVEL|              2211|2026-02-15T12:45:...|                1|        12|04c69c785a7e2c3f1...|INJURY AND / OR T...|  OVER $1,500|2026-02-15T12:48:...|         NO CONTROLS|             TURNING|             0|                      0|                     2|                          2|                            0|             2|               0|                  NULL|41.6840538707|          DAYLIGHT|{"type": "Point",...|-87.7149980023|NONINCAPACITATING...|        2|                35|         NOT APPLICABLE|            ON SCENE|    UNKNOWN|                 DRY|        NOT APPLICABLE|               S|      HAMLIN AVE|    11499|           NO CONTROLS|         NOT DIVIDED|            CLEAR|              NULL|         NULL|              NULL|            NULL|          NULL|       NULL|     NULL|2026-02-18 17:55:...|          2|      2026|
# |                       30|STRAIGHT AND LEVEL|              1131|2026-02-15T12:30:...|                1|        12|661654bdec470e8aa...|NO INJURY / DRIVE...|$501 - $1,500|2026-02-15T12:58:...|         NO CONTROLS|PARKED MOTOR VEHICLE|             0|                      0|                     1|                          0|                            0|             0|               0|                  NULL|41.8754154581|          DAYLIGHT|{"type": "Point",...|-87.7375979115|NO INDICATION OF ...|        2|                30|    UNABLE TO DETERMINE|NOT ON SCENE (DES...|    UNKNOWN|             UNKNOWN|        NOT APPLICABLE|               S|    KILBOURN AVE|      351|           NO CONTROLS|             ONE-WAY|          UNKNOWN|              NULL|            Y|              NULL|            NULL|          NULL|       NULL|     NULL|2026-02-18 17:55:...|          2|      2026|
# |                       43|STRAIGHT AND LEVEL|              1235|2026-02-15T12:30:...|                1|        12|7ea3ec0b632a1d77b...|NO INJURY / DRIVE...|  OVER $1,500|2026-02-15T15:37:...|         NO CONTROLS|PARKED MOTOR VEHICLE|             0|                      0|                     1|                          0|                            0|             0|               0|                  NULL|41.8567796314|          DAYLIGHT|{"type": "Point",...|-87.6512451764|NO INDICATION OF ...|        2|                30|    UNABLE TO DETERMINE|NOT ON SCENE (DES...| NO DEFECTS|             UNKNOWN|        NOT APPLICABLE|               W|         19TH ST|      976|           NO CONTROLS|         NOT DIVIDED|            CLEAR|              NULL|            Y|              NULL|               Y|          NULL|       NULL|     NULL|2026-02-18 17:55:...|          2|      2026|
# |                        3|STRAIGHT AND LEVEL|              2512|2026-02-15T12:23:...|                1|        12|52ecdb3113d6de124...|NO INJURY / DRIVE...|  OVER $1,500|2026-02-15T13:25:...|         NO CONTROLS|        REAR TO SIDE|             0|                      0|                     2|                          0|                            0|             0|               0|                  NULL|41.9292566877|          DAYLIGHT|{"type": "Point",...| -87.785795165|NO INDICATION OF ...|        2|                10|    UNABLE TO DETERMINE|NOT ON SCENE (DES...|    UNKNOWN|                 DRY|        NOT APPLICABLE|               N|NARRAGANSETT AVE|     2700|           NO CONTROLS|         PARKING LOT|            CLEAR|              NULL|         NULL|                 Y|            NULL|          NULL|       NULL|     NULL|2026-02-18 17:55:...|          2|      2026|
# |                       16|STRAIGHT AND LEVEL|              1814|2026-02-15T12:20:...|                1|        12|63448f51ac12aff0f...|NO INJURY / DRIVE...|  OVER $1,500|2026-02-15T12:50:...|FUNCTIONING PROPERLY|             TURNING|             0|                      0|                     2|                          0|                            0|             0|               0|                     Y|41.9220887093|          DAYLIGHT|{"type": "Point",...|-87.6358723379|NO INDICATION OF ...|        2|                25|    UNABLE TO DETERMINE|NOT ON SCENE (DES...| NO DEFECTS|                 DRY|        NOT APPLICABLE|               N|     STOCKTON DR|     2200|     STOP SIGN/FLASHER|      T-INTERSECTION|            CLEAR|                 Y|         NULL|              NULL|            NULL|             Y|       NULL|     NULL|2026-02-18 17:55:...|          2|      2026|
# |                        6|STRAIGHT AND LEVEL|              1834|2026-02-15T12:15:...|                1|        12|cab96de7b2ef8bfc9...|NO INJURY / DRIVE...|  OVER $1,500|2026-02-15T13:15:...|FUNCTIONING PROPERLY|SIDESWIPE SAME DI...|             0|                      0|                     3|                          0|                            0|             0|               0|                     Y|41.8909938691|          DAYLIGHT|{"type": "Point",...| -87.614049826|NO INDICATION OF ...|        2|                30|   FAILING TO REDUCE...|            ON SCENE| NO DEFECTS|                 DRY|        NOT APPLICABLE|               E|     ILLINOIS ST|      525|        TRAFFIC SIGNAL|             ONE-WAY|            CLEAR|              NULL|         NULL|              NULL|            NULL|          NULL|       NULL|     NULL|2026-02-18 17:55:...|          2|      2026|
# |                       18|STRAIGHT AND LEVEL|              1621|2026-02-15T12:08:...|                1|        12|0a518d6851aea2c40...|NO INJURY / DRIVE...|  OVER $1,500|2026-02-15T12:11:...|FUNCTIONING PROPERLY|             TURNING|             0|                      0|                     3|                          0|                            0|             0|               0|                     Y|41.9951116381|          DAYLIGHT|{"type": "Point",...| -87.764752918|NO INDICATION OF ...|        2|                30|   FAILING TO YIELD ...|            ON SCENE| NO DEFECTS|                 DRY|  FAILING TO YIELD ...|               N|     CENTRAL AVE|     6224|        TRAFFIC SIGNAL|         NOT DIVIDED|            CLEAR|              NULL|         NULL|              NULL|            NULL|          NULL|       NULL|     NULL|2026-02-18 17:55:...|          2|      2026|
# |                        6|STRAIGHT AND LEVEL|              1833|2026-02-15T12:00:...|                1|        12|6739f655421637722...|NO INJURY / DRIVE...|$501 - $1,500|2026-02-15T17:00:...|FUNCTIONING PROPERLY|SIDESWIPE SAME DI...|             0|                      0|                     2|                          0|                            0|             0|               0|                  NULL|41.8964553134|          DAYLIGHT|{"type": "Point",...|-87.6256451665|NO INDICATION OF ...|        2|                30|   FAILING TO YIELD ...|NOT ON SCENE (DES...|    UNKNOWN|             UNKNOWN|   IMPROPER LANE USAGE|               N|         RUSH ST|      750|        TRAFFIC SIGNAL|             ONE-WAY|            CLEAR|              NULL|         NULL|              NULL|            NULL|          NULL|       NULL|     NULL|2026-02-18 17:55:...|          2|      2026|
# |                       15|STRAIGHT AND LEVEL|              2032|2026-02-15T12:00:...|                1|        12|abbdad865fa7c3f60...|NO INJURY / DRIVE...|  OVER $1,500|2026-02-15T16:45:...|             UNKNOWN|PARKED MOTOR VEHICLE|             0|                      0|                     1|                          0|                            0|             0|               0|                  NULL|41.9689262366|           UNKNOWN|{"type": "Point",...|-87.6745864921|NO INDICATION OF ...|        2|                30|         NOT APPLICABLE|NOT ON SCENE (DES...|    UNKNOWN|             UNKNOWN|        NOT APPLICABLE|               W|    LAWRENCE AVE|     1800|               UNKNOWN|             UNKNOWN|          UNKNOWN|              NULL|            Y|              NULL|            NULL|          NULL|       NULL|     NULL|2026-02-18 17:55:...|          2|      2026|
# |                       23|STRAIGHT AND LEVEL|               715|2026-02-15T12:00:...|                1|        12|cbce2d3fa21873a6a...|NO INJURY / DRIVE...|  OVER $1,500|2026-02-15T12:40:...|         NO CONTROLS|PARKED MOTOR VEHICLE|             0|                      0|                     1|                          0|                            0|             0|               0|                  NULL|41.7932753823|          DAYLIGHT|{"type": "Point",...|-87.6659287274|NO INDICATION OF ...|        3|                30|   IMPROPER TURNING/...|            ON SCENE|    UNKNOWN|                 DRY|   UNABLE TO DETERMINE|               S|  MARSHFIELD AVE|     5510|           NO CONTROLS|             ONE-WAY|            CLEAR|              NULL|            N|              NULL|            NULL|          NULL|       NULL|     NULL|2026-02-18 17:55:...|          2|      2026|
# |                       15|STRAIGHT AND LEVEL|              2033|2026-02-15T11:45:...|                1|        11|1866033db1dbdc2ce...|INJURY AND / OR T...|  OVER $1,500|2026-02-16T01:15:...|         NO CONTROLS|        OTHER OBJECT|             0|                      0|                     1|                          1|                            0|             1|               0|                     Y|41.9725155227|          DAYLIGHT|{"type": "Point",...|-87.6677639965|NONINCAPACITATING...|        2|                25|   IMPROPER TURNING/...|NOT ON SCENE (DES...|    UNKNOWN|                 DRY|  OPERATING VEHICLE...|               N|        CLARK ST|     4945|     STOP SIGN/FLASHER|         NOT DIVIDED|            CLEAR|              NULL|         NULL|              NULL|            NULL|          NULL|       NULL|     NULL|2026-02-18 17:55:...|          2|      2026|
# |                        6|STRAIGHT AND LEVEL|              1834|2026-02-15T11:42:...|                1|        11|797303e0a4575a64c...|NO INJURY / DRIVE...|$501 - $1,500|2026-02-15T11:42:...|         NO CONTROLS|SIDESWIPE SAME DI...|             0|                      0|                     5|                          0|                            0|             0|               0|                  NULL|41.8950607857|          DAYLIGHT|{"type": "Point",...|-87.6235075091|NO INDICATION OF ...|        2|                30|       IMPROPER BACKING|            ON SCENE|    UNKNOWN|                 DRY|        NOT APPLICABLE|               E|        HURON ST|      150|           NO CONTROLS|             ONE-WAY|            CLEAR|              NULL|         NULL|              NULL|            NULL|          NULL|       NULL|     NULL|2026-02-18 17:55:...|          2|      2026|
# +-------------------------+------------------+------------------+--------------------+-----------------+----------+--------------------+--------------------+-------------+--------------------+--------------------+--------------------+--------------+-----------------------+----------------------+---------------------------+-----------------------------+--------------+----------------+----------------------+-------------+------------------+--------------------+--------------+--------------------+---------+------------------+-----------------------+--------------------+-----------+--------------------+----------------------+----------------+----------------+---------+----------------------+--------------------+-----------------+------------------+-------------+------------------+----------------+--------------+-----------+---------+--------------------+-----------+----------+
# only showing top 20 rows
