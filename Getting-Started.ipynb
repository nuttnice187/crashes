# %% [markdown]
# <a href="https://colab.research.google.com/github/nuttnice187/crashes/blob/dev/Getting-Started.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Getting Started

# %%
# !git clone -b dev https://github.com/nuttnice187/crashes.git

# %%
# !python crashes/entry.py --job data_capture --task ingestion

# %%
from pyspark.sql import SparkSession

spark = SparkSession.getActiveSession()
ingested = spark.read.parquet('/Volumes/workspace/google_drive/mock_s3')

# %% [markdown]
# There are initially 1000 rows from the first ingestion historically loaded.

# %%
ingested.display()

# %%
from argparse import Namespace

args = Namespace(
    job='change_feed', 
    task='curation', 
    api_url=None, 
    source_path='/Volumes/workspace/google_drive/mock_s3', 
    target_path='workspace.google_drive.curate_crashes', 
    run_id='1'
)

# %%
from entry import L
from change_feed.curation import main

main(spark, L, args)

# %%
from pyspark.sql import DataFrame
curated: DataFrame = spark.read.table('workspace.google_drive.curate_crashes')

# %%
curated.display()

# %%
args.run_id = "2"
args.run_id

# %% [markdown]
# After one new crash record has been ingested to the data capture layer we will run for the second time

# %%
main(spark, L, args)

# %% [markdown]
# Now, there is a new crash record for the first time in the ingestion layer to append to curated silver layer after transformation.

# %%
# %sql
SELECT DISTINCT ingest_time FROM workspace.google_drive.curate_crashes

# %% [markdown]
# Now, there are 1001 rows.

# %%
# %sql
SELECT DISTINCT * FROM workspace.google_drive.curate_crashes
