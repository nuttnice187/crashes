# %% [markdown]
# <a href="https://colab.research.google.com/github/nuttnice187/crashes/blob/dev/Getting-Started.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Getting Started

# %%
# !git clone -b dev https://github.com/nuttnice187/crashes.git
# Out:
# Cloning into 'crashes'...
# remote: Enumerating objects: 311, done.
# remote: Counting objects: 100% (183/183), done.
# remote: Compressing objects: 100% (135/135), done.
# remote: Total 311 (delta 73), reused 69 (delta 26), pack-reused 128 (from 1)
# Receiving objects: 100% (311/311), 100.89 KiB | 2.06 MiB/s, done.
# Resolving deltas: 100% (118/118), done.

# %%
# !python crashes/entry.py --job data_capture --task ingestion
# Out:
# 2026-02-11 17:41:17,392 - __main__ - INFO - Namespace(job='data_capture', task='ingestion', api_url=None, source_path=None, target_path=None, run_id=None)
# 2026-02-11 17:41:17,393 - __main__ - INFO - Added 'crashes' to sys.path
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/02/11 17:41:25 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 2026-02-11 17:41:58,349 - __main__ - INFO - Successfully read existing Parquet data from /content/drive/MyDrive/crashes_data. Row count: 1000
# 26/02/11 17:41:59 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# 2026-02-11 17:42:05,118 - __main__ - INFO - Performed left_anti join with existing data on 'crash_record_id'. New records count: 226

# %%
from pyspark.sql import DataFrame, SparkSession

spark = SparkSession.builder.getOrCreate()
post_load = spark.read.parquet('drive/MyDrive/crashes_data')

post_load.count()
# Out:
# 1226

# %%
post_load.show()
# Out:
# +-------------------------+------------------+------------------+--------------------+-----------------+----------+-----------+--------------------+--------------------+-------------+--------------------+--------------------+--------------------+--------------+-----------------------+----------------------+---------------------------+-----------------------------+--------------+----------------+-------------+--------------------+--------------------+--------------+--------------------+---------+------------------+-----------------------+--------------------+-----------+--------------------+----------------------+----------------+-------------+---------+----------------------+--------------------+-----------------+----------------------+-------------+--------------+------------------+----------------+------------------+---------+-----------+--------------+-----------------+--------------------+
# |computed_region_rpca_8um6|         alignment|beat_of_occurrence|          crash_date|crash_day_of_week|crash_hour|crash_month|     crash_record_id|          crash_type|       damage|date_police_notified|    device_condition|    first_crash_type|injuries_fatal|injuries_incapacitating|injuries_no_indication|injuries_non_incapacitating|injuries_reported_not_evident|injuries_total|injuries_unknown|     latitude|  lighting_condition|            location|     longitude|  most_severe_injury|num_units|posted_speed_limit|prim_contributory_cause|         report_type|road_defect|roadway_surface_cond|sec_contributory_cause|street_direction|  street_name|street_no|traffic_control_device|     trafficway_type|weather_condition|intersection_related_i|hit_and_run_i|photos_taken_i|statements_taken_i|crash_date_est_i|private_property_i|dooring_i|work_zone_i|work_zone_type|workers_present_i|         ingest_time|
# +-------------------------+------------------+------------------+--------------------+-----------------+----------+-----------+--------------------+--------------------+-------------+--------------------+--------------------+--------------------+--------------+-----------------------+----------------------+---------------------------+-----------------------------+--------------+----------------+-------------+--------------------+--------------------+--------------+--------------------+---------+------------------+-----------------------+--------------------+-----------+--------------------+----------------------+----------------+-------------+---------+----------------------+--------------------+-----------------+----------------------+-------------+--------------+------------------+----------------+------------------+---------+-----------+--------------+-----------------+--------------------+
# |                        3|STRAIGHT AND LEVEL|              2512|2026-02-07T17:16:...|                7|        17|          2|bd492a36aedb540ab...|NO INJURY / DRIVE...|  OVER $1,500|2026-02-07T17:30:...|         NO CONTROLS|PARKED MOTOR VEHICLE|             0|                      0|                     2|                          0|                            0|             0|               0|41.9237604017|                DUSK|{"type": "Point",...|-87.7887477626|NO INDICATION OF ...|        2|                10|    UNABLE TO DETERMINE|NOT ON SCENE (DES...| NO DEFECTS|                 DRY|   UNABLE TO DETERMINE|               W|FULLERTON AVE|     6520|           NO CONTROLS|         PARKING LOT|            CLEAR|                  NULL|            Y|          NULL|              NULL|            NULL|              NULL|     NULL|       NULL|          NULL|             NULL|2026-02-11 15:59:...|
# |                       16|STRAIGHT AND LEVEL|              1935|2026-02-07T17:15:...|                7|        17|          2|aa549cebbb3457837...|NO INJURY / DRIVE...|$501 - $1,500|2026-02-07T21:15:...|FUNCTIONING PROPERLY|PARKED MOTOR VEHICLE|             0|                      0|                     1|                          0|                            0|             0|               0|41.9314416131|                DUSK|{"type": "Point",...|-87.6488214963|NO INDICATION OF ...|        2|                30|   IMPROPER OVERTAKI...|NOT ON SCENE (DES...| NO DEFECTS|                 DRY|   UNABLE TO DETERMINE|               W| SCHUBERT AVE|      757|     STOP SIGN/FLASHER|         NOT DIVIDED|            CLEAR|                     Y|         NULL|          NULL|              NULL|            NULL|              NULL|     NULL|       NULL|          NULL|             NULL|2026-02-11 15:59:...|
# |                       61|STRAIGHT AND LEVEL|               323|2026-02-07T17:15:...|                7|        17|          2|aef67a6066dd77a59...|NO INJURY / DRIVE...|$501 - $1,500|2026-02-08T09:10:...|FUNCTIONING PROPERLY|            REAR END|             0|                      0|                     2|                          0|                            0|             0|               0|41.7653442552|             UNKNOWN|{"type": "Point",...|-87.6248230991|NO INDICATION OF ...|        2|                30|    UNABLE TO DETERMINE|NOT ON SCENE (DES...|    UNKNOWN|             UNKNOWN|   UNABLE TO DETERMINE|               E|      71ST ST|        1|        TRAFFIC SIGNAL|         NOT DIVIDED|          UNKNOWN|                     Y|         NULL|          NULL|              NULL|            NULL|              NULL|     NULL|       NULL|          NULL|             NULL|2026-02-11 15:59:...|
# |                       57|STRAIGHT AND LEVEL|              1031|2026-02-07T17:10:...|                7|        17|          2|15b3575dc1f9f0e50...|NO INJURY / DRIVE...|$501 - $1,500|2026-02-07T17:35:...|         NO CONTROLS|            REAR END|             0|                      0|                     3|                          0|                            0|             0|               0|41.8370851389|                DUSK|{"type": "Point",...|-87.7190967969|NO INDICATION OF ...|        2|                30|   FOLLOWING TOO CLO...|NOT ON SCENE (DES...| NO DEFECTS|                 DRY|  FOLLOWING TOO CLO...|               W|      31ST ST|     3750|           NO CONTROLS|         NOT DIVIDED|            CLEAR|                  NULL|         NULL|          NULL|              NULL|            NULL|              NULL|     NULL|       NULL|          NULL|             NULL|2026-02-11 15:59:...|
# |                        6|STRAIGHT AND LEVEL|              1834|2026-02-07T17:06:...|                7|        17|          2|d68ab4506a55afce1...|INJURY AND / OR T...|  OVER $1,500|2026-02-07T17:10:...|FUNCTIONING PROPERLY|SIDESWIPE SAME DI...|             0|                      0|                     2|                          0|                            1|             1|               0|41.8949034326|                DUSK|{"type": "Point",...|-87.6241041941|REPORTED, NOT EVI...|        3|                30|    IMPROPER LANE USAGE|            ON SCENE| NO DEFECTS|                 DRY|        NOT APPLICABLE|               N| MICHIGAN AVE|      679|        TRAFFIC SIGNAL|DIVIDED - W/MEDIA...|            CLEAR|                     Y|         NULL|          NULL|              NULL|            NULL|              NULL|     NULL|       NULL|          NULL|             NULL|2026-02-11 15:59:...|
# |                       34|STRAIGHT AND LEVEL|               122|2026-02-07T17:05:...|                7|        17|          2|6920a7c576b7123ed...|NO INJURY / DRIVE...|$501 - $1,500|2026-02-07T18:22:...|             UNKNOWN|SIDESWIPE SAME DI...|             0|                      0|                     2|                          0|                            0|             0|               0|41.8806951295|             UNKNOWN|{"type": "Point",...|-87.6336524586|NO INDICATION OF ...|        2|                30|   DRIVING SKILLS/KN...|NOT ON SCENE (DES...|    UNKNOWN|             UNKNOWN|   UNABLE TO DETERMINE|               S|     WELLS ST|       51|               UNKNOWN|             ONE-WAY|          UNKNOWN|                  NULL|         NULL|          NULL|              NULL|            NULL|              NULL|     NULL|       NULL|          NULL|             NULL|2026-02-11 15:59:...|
# |                       21|STRAIGHT AND LEVEL|              1722|2026-02-07T17:05:...|                7|        17|          2|afc49f8505c35b4d8...|NO INJURY / DRIVE...|  OVER $1,500|2026-02-07T17:20:...|FUNCTIONING PROPERLY|SIDESWIPE SAME DI...|             0|                      0|                     2|                          0|                            0|             0|               0|41.9608162577|            DAYLIGHT|{"type": "Point",...|-87.7297587944|NO INDICATION OF ...|        2|                30|    IMPROPER LANE USAGE|NOT ON SCENE (DES...| NO DEFECTS|                 DRY|   UNABLE TO DETERMINE|               W| MONTROSE AVE|     4101|        TRAFFIC SIGNAL|DIVIDED - W/MEDIA...|            CLEAR|                  NULL|         NULL|          NULL|              NULL|            NULL|              NULL|     NULL|       NULL|          NULL|             NULL|2026-02-11 15:59:...|
# |                       60|STRAIGHT AND LEVEL|               232|2026-02-07T17:01:...|                7|        17|          2|24b45b77bce1ba145...|INJURY AND / OR T...|  OVER $1,500|2026-02-07T17:01:...|FUNCTIONING PROPERLY|               ANGLE|             0|                      0|                     3|                          0|                            0|             0|               0|41.7891865885|DARKNESS, LIGHTED...|{"type": "Point",...|-87.6191627896|NO INDICATION OF ...|        2|                30|   FAILING TO YIELD ...|            ON SCENE|    UNKNOWN|                 DRY|  FAILING TO YIELD ...|               E|      58TH ST|      299|     STOP SIGN/FLASHER|DIVIDED - W/MEDIA...|            CLEAR|                     Y|         NULL|          NULL|                 Y|            NULL|              NULL|     NULL|       NULL|          NULL|             NULL|2026-02-11 15:59:...|
# |                       37|STRAIGHT AND LEVEL|               934|2026-02-07T17:00:...|                7|        17|          2|3860aacd5f7099b00...|INJURY AND / OR T...|  OVER $1,500|2026-02-07T17:18:...|FUNCTIONING PROPERLY|               ANGLE|             0|                      0|                     3|                          0|                            1|             1|               0| 41.801408357|            DAYLIGHT|{"type": "Point",...|-87.6500802381|REPORTED, NOT EVI...|        2|                30|   DISREGARDING TRAF...|            ON SCENE| NO DEFECTS|                 DRY|        NOT APPLICABLE|               W|      51ST ST|      959|        TRAFFIC SIGNAL|            FOUR WAY|  CLOUDY/OVERCAST|                     Y|            Y|          NULL|              NULL|               Y|              NULL|     NULL|       NULL|          NULL|             NULL|2026-02-11 15:59:...|
# |                       55|STRAIGHT AND LEVEL|              1831|2026-02-07T17:00:...|                7|        17|          2|829036291b51569b8...|NO INJURY / DRIVE...|  OVER $1,500|2026-02-07T19:20:...|         NO CONTROLS|PARKED MOTOR VEHICLE|             0|                      0|                     1|                          0|                            0|             0|               0|41.8923351748|DARKNESS, LIGHTED...|{"type": "Point",...|-87.6369067156|NO INDICATION OF ...|        2|                30|   IMPROPER OVERTAKI...|NOT ON SCENE (DES...|    UNKNOWN|             UNKNOWN|  FAILING TO REDUCE...|               N|   ORLEANS ST|      563|     STOP SIGN/FLASHER|DIVIDED - W/MEDIA...|          UNKNOWN|                  NULL|         NULL|          NULL|              NULL|            NULL|              NULL|     NULL|       NULL|          NULL|             NULL|2026-02-11 15:59:...|
# |                       57|STRAIGHT AND LEVEL|              1024|2026-02-07T16:45:...|                7|        16|          2|faf2005b646d1a6a0...|NO INJURY / DRIVE...|  OVER $1,500|2026-02-07T17:40:...|         NO CONTROLS|PARKED MOTOR VEHICLE|             0|                      0|                     1|                          0|                            0|             0|               0|41.8460718228|            DAYLIGHT|{"type": "Point",...|-87.7052341242|NO INDICATION OF ...|        2|                25|    UNABLE TO DETERMINE|NOT ON SCENE (DES...|    UNKNOWN|                 DRY|        NOT APPLICABLE|               S|   KEDZIE AVE|     2506|           NO CONTROLS|               OTHER|            CLEAR|                  NULL|            Y|          NULL|              NULL|            NULL|              NULL|     NULL|       NULL|          NULL|             NULL|2026-02-11 15:59:...|
# |                        4|STRAIGHT AND LEVEL|              1433|2026-02-07T16:30:...|                7|        16|          2|d8672b5a92eadcdf8...|NO INJURY / DRIVE...|  OVER $1,500|2026-02-07T17:10:...|         NO CONTROLS|        REAR TO SIDE|             0|                      0|                     2|                          0|                            0|             0|               0|41.9067951098|            DAYLIGHT|{"type": "Point",...|-87.6677316701|NO INDICATION OF ...|        2|                10|   FAILING TO YIELD ...|NOT ON SCENE (DES...| NO DEFECTS|                 DRY|        NOT APPLICABLE|               N|  ASHLAND AVE|     1360|           NO CONTROLS|         PARKING LOT|            CLEAR|                  NULL|         NULL|          NULL|              NULL|            NULL|              NULL|     NULL|       NULL|          NULL|             NULL|2026-02-11 15:59:...|
# |                       30|STRAIGHT AND LEVEL|              1122|2026-02-07T16:25:...|                7|        16|          2|313799645382a85fe...|NO INJURY / DRIVE...|  OVER $1,500|2026-02-07T16:30:...|FUNCTIONING PROPERLY|            REAR END|             0|                      0|                     2|                          0|                            0|             0|               0|41.8819885724|            DAYLIGHT|{"type": "Point",...|-87.7255608436|NO INDICATION OF ...|        2|                30|    UNABLE TO DETERMINE|NOT ON SCENE (DES...| NO DEFECTS|                 DRY|        NOT APPLICABLE|               N|   PULASKI RD|      105|        TRAFFIC SIGNAL|         NOT DIVIDED|            CLEAR|                  NULL|            Y|          NULL|              NULL|            NULL|              NULL|     NULL|       NULL|          NULL|             NULL|2026-02-11 15:59:...|
# |                       58|STRAIGHT AND LEVEL|               824|2026-02-07T16:20:...|                7|        16|          2|aa6cfdc97fd21e39d...|NO INJURY / DRIVE...|  OVER $1,500|2026-02-09T17:00:...|             UNKNOWN|SIDESWIPE SAME DI...|             0|                      0|                     2|                          0|                            0|             0|               0|41.7933705543|            DAYLIGHT|{"type": "Point",...|-87.6841753768|NO INDICATION OF ...|        2|                30|    UNABLE TO DETERMINE|NOT ON SCENE (DES...|    UNKNOWN|             UNKNOWN|   UNABLE TO DETERMINE|               S|  WESTERN AVE|     5500|               UNKNOWN|             UNKNOWN|            CLEAR|                  NULL|         NULL|          NULL|              NULL|            NULL|              NULL|     NULL|       NULL|          NULL|             NULL|2026-02-11 15:59:...|
# |                       39|STRAIGHT AND LEVEL|              1931|2026-02-07T16:16:...|                7|        16|          2|24b4d92aa8e5a2e78...|INJURY AND / OR T...|  OVER $1,500|2026-02-07T16:18:...|FUNCTIONING PROPERLY|        PEDALCYCLIST|             0|                      0|                     1|                          0|                            1|             1|               0|41.9322970111|            DAYLIGHT|{"type": "Point",...|-87.6783610875|REPORTED, NOT EVI...|        2|                30|    UNABLE TO DETERMINE|            ON SCENE| NO DEFECTS|                 DRY|   UNABLE TO DETERMINE|               N| CLYBOURN AVE|     2800|        TRAFFIC SIGNAL| FIVE POINT, OR MORE|            CLEAR|                     Y|         NULL|             Y|                 Y|            NULL|              NULL|     NULL|       NULL|          NULL|             NULL|2026-02-11 15:59:...|
# |                       43|STRAIGHT AND LEVEL|              1233|2026-02-07T16:15:...|                7|        16|          2|195882e0cbdee691b...|NO INJURY / DRIVE...|  OVER $1,500|2026-02-07T16:20:...|FUNCTIONING PROPERLY|            REAR END|             0|                      0|                     3|                          0|                            0|             0|               0|41.8668964805|            DAYLIGHT|{"type": "Point",...|-87.6568252013|NO INDICATION OF ...|        2|                30|    UNABLE TO DETERMINE|            ON SCENE| NO DEFECTS|                 DRY|   UNABLE TO DETERMINE|               S|   RACINE AVE|     1202|        TRAFFIC SIGNAL|         NOT DIVIDED|            CLEAR|                  NULL|         NULL|          NULL|              NULL|            NULL|              NULL|     NULL|       NULL|          NULL|             NULL|2026-02-11 15:59:...|
# |                       14|STRAIGHT AND LEVEL|              2013|2026-02-07T16:10:...|                7|        16|          2|9a450a0fe07b85bca...|NO INJURY / DRIVE...|  OVER $1,500|2026-02-07T16:50:...|FUNCTIONING PROPERLY|SIDESWIPE SAME DI...|             0|                      0|                     2|                          0|                            0|             0|               0|41.9855760454|            DAYLIGHT|{"type": "Point",...|-87.6601764914|NO INDICATION OF ...|        2|                30|    UNABLE TO DETERMINE|NOT ON SCENE (DES...|    UNKNOWN|                 DRY|        NOT APPLICABLE|               W|HOLLYWOOD AVE|     1200|        TRAFFIC SIGNAL|         NOT DIVIDED|            CLEAR|                  NULL|            Y|          NULL|              NULL|               Y|              NULL|     NULL|       NULL|          NULL|             NULL|2026-02-11 15:59:...|
# |                       59|STRAIGHT AND LEVEL|               634|2026-02-07T16:10:...|                7|        16|          2|b61c4a4e844407244...|INJURY AND / OR T...|  OVER $1,500|2026-02-07T16:11:...|         NO CONTROLS|          PEDESTRIAN|             0|                      0|                     5|                          0|                            1|             1|               0|41.7325901368|            DAYLIGHT|{"type": "Point",...|-87.6254857747|REPORTED, NOT EVI...|        2|                30|         NOT APPLICABLE|            ON SCENE|    UNKNOWN|                 DRY|  OPERATING VEHICLE...|               S|LAFAYETTE AVE|     8900|           NO CONTROLS|         PARKING LOT|            CLEAR|                  NULL|            Y|          NULL|              NULL|            NULL|              NULL|     NULL|       NULL|          NULL|             NULL|2026-02-11 15:59:...|
# |                       59|STRAIGHT AND LEVEL|               634|2026-02-07T16:07:...|                7|        16|          2|16e55e5f6ce941d22...|NO INJURY / DRIVE...| $500 OR LESS|2026-02-07T19:20:...|         NO CONTROLS|PARKED MOTOR VEHICLE|             0|                      0|                     1|                          0|                            0|             0|               0|41.7360484858|                DAWN|{"type": "Point",...|-87.6289948739|NO INDICATION OF ...|        2|                30|    UNABLE TO DETERMINE|NOT ON SCENE (DES...| NO DEFECTS|                 DRY|   UNABLE TO DETERMINE|               W|      87TH ST|      201|           NO CONTROLS|         PARKING LOT|            CLEAR|                  NULL|         NULL|          NULL|              NULL|               Y|              NULL|     NULL|       NULL|          NULL|             NULL|2026-02-11 15:59:...|
# |                       48|STRAIGHT AND LEVEL|              1623|2026-02-07T16:06:...|                7|        16|          2|ae26bdcdc700bebe8...|INJURY AND / OR T...| $500 OR LESS|2026-02-07T16:11:...|         NO CONTROLS|  OTHER NONCOLLISION|             0|                      0|                     0|                          1|                            0|             1|               0|41.9759464617|            DAYLIGHT|{"type": "Point",...|-87.7678147669|NONINCAPACITATING...|        1|                30|   ROAD ENGINEERING/...|            ON SCENE| NO DEFECTS|       SNOW OR SLUSH|        NOT APPLICABLE|               N|MILWAUKEE AVE|     5255|           NO CONTROLS|         NOT DIVIDED|            CLEAR|                  NULL|         NULL|          NULL|              NULL|            NULL|              NULL|     NULL|       NULL|          NULL|             NULL|2026-02-11 15:59:...|
# +-------------------------+------------------+------------------+--------------------+-----------------+----------+-----------+--------------------+--------------------+-------------+--------------------+--------------------+--------------------+--------------+-----------------------+----------------------+---------------------------+-----------------------------+--------------+----------------+-------------+--------------------+--------------------+--------------+--------------------+---------+------------------+-----------------------+--------------------+-----------+--------------------+----------------------+----------------+-------------+---------+----------------------+--------------------+-----------------+----------------------+-------------+--------------+------------------+----------------+------------------+---------+-----------+--------------+-----------------+--------------------+
# only showing top 20 rows
