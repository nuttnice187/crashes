# %% [markdown]
# <a href="https://colab.research.google.com/github/nuttnice187/crashes/blob/main/Getting-Started.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Getting Started

# %%
# !git clone https://github.com/nuttnice187/crashes.git
# Out:
# Cloning into 'crashes'...
# remote: Enumerating objects: 970, done.
# remote: Counting objects: 100% (176/176), done.
# remote: Compressing objects: 100% (167/167), done.
# remote: Total 970 (delta 77), reused 16 (delta 7), pack-reused 794 (from 1)
# Receiving objects: 100% (970/970), 1.02 MiB | 7.78 MiB/s, done.
# Resolving deltas: 100% (447/447), done.

# %%
# !python crashes/main.py --job data_capture --task ingestion
# Out:
# 2026-03-03 13:58:05,309 - __main__ - INFO - Added 'crashes' to sys.path
# 2026-03-03 13:58:06,022 - __main__ - INFO - Namespace(job='data_capture', task='ingestion', api_url=None, source_path=None, target_path=None, run_id=None, log_level=None, root=None)
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/03/03 13:58:09 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 2026-03-03 13:58:28,034 - __main__ - INFO - Successfully read existing Parquet data from /content/drive/MyDrive/crashes_data. Row count: 1791
# 2026-03-03 13:58:28,447 - __main__ - WARNING - Schema mismatch detected: [DIFFERENT_SCHEMA] Schemas do not match.
# --- actual
# +++ expected
# ...

# %%
from pyspark.sql import DataFrame, SparkSession

spark = SparkSession.builder.getOrCreate()
post_load = spark.read.parquet('drive/MyDrive/crashes_data')

post_load.count()
# Out:
# 1791

# %%
post_load.printSchema()
# Out:
# root
#  |-- crash_record_id: string (nullable = true)
#  |-- computed_region_rpca_8um6: string (nullable = true)
#  |-- alignment: string (nullable = true)
#  |-- beat_of_occurrence: string (nullable = true)
#  |-- crash_date: string (nullable = true)
#  |-- crash_day_of_week: string (nullable = true)
#  |-- crash_hour: string (nullable = true)
#  |-- crash_type: string (nullable = true)
#  |-- damage: string (nullable = true)
#  |-- date_police_notified: string (nullable = true)
#  |-- device_condition: string (nullable = true)
#  |-- first_crash_type: string (nullable = true)
#  |-- hit_and_run_i: string (nullable = true)
#  |-- injuries_fatal: string (nullable = true)
#  |-- injuries_incapacitating: string (nullable = true)
#  |-- injuries_no_indication: string (nullable = true)
#  |-- injuries_non_incapacitating: string (nullable = true)
#  |-- injuries_reported_not_evident: string (nullable = true)
#  |-- injuries_total: string (nullable = true)
# ...

# %%
post_load.show()
