# %% [markdown]
# <a href="https://colab.research.google.com/github/nuttnice187/crashes/blob/dev/Getting-Started.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Getting Started

# %%
# !git clone -b dev https://github.com/nuttnice187/crashes.git
# Out:
# Cloning into 'crashes'...
# remote: Enumerating objects: 139, done.
# remote: Counting objects: 100% (139/139), done.
# remote: Compressing objects: 100% (124/124), done.
# remote: Total 139 (delta 53), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (139/139), 49.57 KiB | 2.75 MiB/s, done.
# Resolving deltas: 100% (53/53), done.

# %%
# !python crashes/entry.py --job data_capture --task ingestion
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/02/10 15:55:14 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Could not read existing Parquet data from /content/drive/MyDrive/crashes_data: [UNABLE_TO_INFER_SCHEMA] Unable to infer schema for Parquet. It must be specified manually. SQLSTATE: 42KD9. Proceeding without existing data.
# 26/02/10 15:55:30 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.

# %%
from pyspark.sql import DataFrame, SparkSession

spark = SparkSession.builder.getOrCreate()
post_load = spark.read.parquet('drive/MyDrive/crashes_data')

post_load.count()
# Out:
# 1000

# %%
post_load.show()
# Out:
# +-------------------------+------------------+------------------+--------------------+-----------------+----------+-----------+--------------------+--------------------+-------------+--------------------+--------------------+--------------------+--------------+-----------------------+----------------------+---------------------------+-----------------------------+--------------+----------------+-------------+--------------------+--------------------+--------------+--------------------+---------+------------------+-----------------------+--------------------+-----------+--------------------+----------------------+----------------+----------------+---------+----------------------+--------------------+--------------------+----------------------+------------------+-------------+--------------+------------------+----------------+-----------+--------------+-----------------+---------+--------------------+
# |computed_region_rpca_8um6|         alignment|beat_of_occurrence|          crash_date|crash_day_of_week|crash_hour|crash_month|     crash_record_id|          crash_type|       damage|date_police_notified|    device_condition|    first_crash_type|injuries_fatal|injuries_incapacitating|injuries_no_indication|injuries_non_incapacitating|injuries_reported_not_evident|injuries_total|injuries_unknown|     latitude|  lighting_condition|            location|     longitude|  most_severe_injury|num_units|posted_speed_limit|prim_contributory_cause|         report_type|road_defect|roadway_surface_cond|sec_contributory_cause|street_direction|     street_name|street_no|traffic_control_device|     trafficway_type|   weather_condition|intersection_related_i|statements_taken_i|hit_and_run_i|photos_taken_i|private_property_i|crash_date_est_i|work_zone_i|work_zone_type|workers_present_i|dooring_i|         update_time|
# +-------------------------+------------------+------------------+--------------------+-----------------+----------+-----------+--------------------+--------------------+-------------+--------------------+--------------------+--------------------+--------------+-----------------------+----------------------+---------------------------+-----------------------------+--------------+----------------+-------------+--------------------+--------------------+--------------+--------------------+---------+------------------+-----------------------+--------------------+-----------+--------------------+----------------------+----------------+----------------+---------+----------------------+--------------------+--------------------+----------------------+------------------+-------------+--------------+------------------+----------------+-----------+--------------+-----------------+---------+--------------------+
# |                       58|STRAIGHT AND LEVEL|               831|2026-02-06T18:35:...|                6|        18|          2|9635f934a24544da0...|NO INJURY / DRIVE...| $500 OR LESS|2026-02-06T20:04:...|         NO CONTROLS|SIDESWIPE SAME DI...|             0|                      0|                     2|                          0|                            0|             0|               0|41.7652714928|DARKNESS, LIGHTED...|{"type": "Point",...|-87.7029549653|NO INDICATION OF ...|        2|                30|    UNABLE TO DETERMINE|NOT ON SCENE (DES...| NO DEFECTS|                 DRY|   UNABLE TO DETERMINE|               W|     REDFIELD DR|     3200|           NO CONTROLS|             ONE-WAY|               CLEAR|                  NULL|              NULL|            Y|          NULL|              NULL|            NULL|       NULL|          NULL|             NULL|     NULL|2026-02-10 15:55:...|
# |                       57|STRAIGHT AND LEVEL|              1033|2026-02-06T18:28:...|                6|        18|          2|7e187c9c709633965...|NO INJURY / DRIVE...|  OVER $1,500|2026-02-08T18:15:...|         NO CONTROLS|        FIXED OBJECT|             0|                      0|                     1|                          0|                            0|             0|               0|41.8444242271|DARKNESS, LIGHTED...|{"type": "Point",...|-87.7035768072|NO INDICATION OF ...|        1|                15|    UNABLE TO DETERMINE|NOT ON SCENE (DES...|    UNKNOWN|                 WET|   UNABLE TO DETERMINE|               W|         26TH ST|     3123|           NO CONTROLS|         PARKING LOT|               CLEAR|                  NULL|              NULL|         NULL|          NULL|                 Y|            NULL|       NULL|          NULL|             NULL|     NULL|2026-02-10 15:55:...|
# |                       18|STRAIGHT AND LEVEL|              1611|2026-02-06T18:22:...|                6|        18|          2|61b797493eb17e8f3...|INJURY AND / OR T...|  OVER $1,500|2026-02-06T18:25:...|         NO CONTROLS|PARKED MOTOR VEHICLE|             0|                      0|                     1|                          0|                            0|             0|               0|41
NO INDICATION OF ...|        2|                30|    UNABLE TO DETERMINE|NOT ON SCENE (DES...| NO DEFECTS|                 DRY|        NOT APPLICABLE|               N|   MILWAUKEE AVE|     1201|        TRAFFIC SIGNAL|         NOT DIVIDED|               CLEAR|                     Y|              NULL|            Y|          NULL|              NULL|            NULL|       NULL|          NULL|             NULL|     NULL|2026-02-10 15:55:...|
# |                       56|STRAIGHT AND LEVEL|               815|2026-02-06T18:07:...|                6|        18|          2|a959cae809412af76...|NO INJURY / DRIVE...|$501 - $1,500|2026-02-06T18:27:...|         NO CONTROLS|            REAR END|             0|                      0|                     2|                          0|                            0|             0|               0|41.7932935692|            DARKNESS|{"type": "Point",...|-87.7233091848|NO INDICATION OF ...|        2|                30|   FOLLOWING TOO CLO...|NOT ON SCENE (DES...| NO DEFECTS|                 DRY|        NOT APPLICABLE|               S|      PULASKI RD|     5498|           NO CONTROLS|         NOT DIVIDED|               CLEAR|                  NULL|              NULL|            Y|          NULL|              NULL|            NULL|       NULL|          NULL|             NULL|     NULL|2026-02-10 15:55:...|
# |                       34|STRAIGHT AND LEVEL|               112|2026-02-06T18:04:...|                6|        18|          2|8e5ac54b2d0527732...|NO INJURY / DRIVE...|$501 - $1,500|2026-02-07T14:42:...|         NO CONTROLS|SIDESWIPE SAME DI...|             0|                      0|                     2|                          0|                            0|             0|               0|41.8809959971|            DAYLIGHT|{"type": "Point",...|-87.6263230504|NO INDICATION OF ...|        2|                30|    UNABLE TO DETERMINE|NOT ON SCENE (DES...| NO DEFECTS|                 DRY|   UNABLE TO DETERMINE|               S|      WABASH AVE|       44|           NO CONTROLS|         NOT DIVIDED|               CLEAR|                  NULL|              NULL|         NULL|          NULL|              NULL|            NULL|       NULL|          NULL|             NULL|     NULL|2026-02-10 15:55:...|
# |                       58|STRAIGHT AND LEVEL|               823|2026-02-06T18:00:...|                6|        18|          2|2af7c967d01e258a1...|NO INJURY / DRIVE...|  OVER $1,500|2026-02-07T11:40:...|         NO CONTROLS|PARKED MOTOR VEHICLE|             0|                      0|                     1|                          0|                            0|             0|               0|41.7822192456|             UNKNOWN|{"type": "Point",...|-87.7206869623|NO INDICATION OF ...|        2|                30|    UNABLE TO DETERMINE|NOT ON SCENE (DES...| NO DEFECTS|             UNKNOWN|        NOT APPLICABLE|               W|         61ST ST|     3905|           NO CONTROLS|             ONE-WAY|             UNKNOWN|                  NULL|              NULL|            Y|          NULL|              NULL|               Y|       NULL|          NULL|             NULL|     NULL|2026-02-10 15:55:...|
# |                        2|STRAIGHT AND LEVEL|              2513|2026-02-06T18:00:...|                6|        18|          2|9b03a030428a58618...|INJURY AND / OR T...|  OVER $1,500|2026-02-06T18:00:...|FUNCTIONING PROPERLY|          PEDESTRIAN|             0|                      0|                     1|                          1|                            0|             1|               0|41.9129679707|DARKNESS, LIGHTED...|{"type": "Point",...|-87.7754930343|NONINCAPACITATING...|        2|                30|    UNABLE TO DETERMINE|            ON SCENE| NO DEFECTS|                 DRY|   UNABLE TO DETERMINE|               N|      AUSTIN AVE|     1800|        TRAFFIC SIGNAL|            FOUR WAY|               CLEAR|                     Y|              NULL|         NULL|          NULL|              NULL|            NULL|       NULL|          NULL|             NULL|     NULL|2026-02-10 15:55:...|
# |                       34| STRAIGHT ON GRADE|               114|2026-02-06T18:00:...|                6|        18|          2|d120cc4508c1a6b29...|INJURY AND / OR T...|  OVER $1,500|2026-02-06T18:02:...|         NO CONTROLS|        FIXED OBJECT|             0|                      0|                     2|                          0|                            0|             0|               0|41.8795834575|DARKNESS, LIGHTED...|{"type": "Point",...|-87.6176071169|NO INDICATION OF ...|        1|                40|   ROAD ENGINEERING/...|            ON SCENE| RUT, HOLES|                 WET|        NOT APPLICABLE|               S|LAKE SHORE DR NB|      200|           NO CONTROLS|DIVIDED - W/MEDIA...|     CLOUDY/OVERCAST|                  NULL|              NULL|         NULL|          NULL|              NULL|            NULL|       NULL|          NULL|             NULL|     NULL|2026-02-10 15:55:...|
# |                       59|STRAIGHT AND LEVEL|               622|2026-02-06T18:00:...|                6|        18|          2|d3ea3b78e91dc26ea...|NO INJURY / DRIVE...|  OVER $1,500|2026-02-06T20:12:...|FUNCTIONING PROPERLY|             TURNING|             0|                      0|                     2|                          0|                            0|             0|               0|41.7435045576|            DAYLIGHT|{"type": "Point",...|-87.6366627981|NO INDICATION OF ...|        2|                30|    UNABLE TO DETERMINE|NOT ON SCENE (DES...| NO DEFECTS|                 DRY|        NOT APPLICABLE|               S|   VINCENNES AVE|     8300|        TRAFFIC SIGNAL|         NOT DIVIDED|               CLEAR|                     N|              NULL|            Y|          NULL|              NULL|            NULL|       NULL|          NULL|             NULL|     NULL|2026-02-10 15:55:...|
# |                       25|STRAIGHT AND LEVEL|               431|2026-02-06T17:51:...|                6|        17|          2|9ed78904b29d5336f...|NO INJURY / DRIVE...| $500 OR LESS|2026-02-06T18:20:...|         NO CONTROLS|             TURNING|             0|                      0|                     2|                          0|                            0|             0|               0|41.7223586602|DARKNESS, LIGHTED...|{"type": "Point",...|-87.5754142536|NO INDICATION OF ...|        2|                25|   FAILING TO YIELD ...|NOT ON SCENE (DES...| NO DEFECTS|                 DRY|        NOT APPLICABLE|               E|         95TH ST|     1999|           NO CONTROLS|         NOT DIVIDED|               CLEAR|                  NULL|              NULL|         NULL|          NULL|              NULL|            NULL|       NULL|          NULL|             NULL|     NULL|2026-02-10 15:55:...|
# |                       39|STRAIGHT AND LEVEL|              1931|2026-02-06T17:48:...|                6|        17|          2|6fcc4d28f9378ee6f...|NO INJURY / DRIVE...| $500 OR LESS|2026-02-06T18:30:...|         NO CONTROLS|PARKED MOTOR VEHICLE|             0|                      0|                     1|                          0|                            0|             0|               0|41.9385043894|DARKNESS, LIGHTED...|{"type": "Point",...|-87.6822276838|NO INDICATION OF ...|        2|                25|       IMPROPER BACKING|NOT ON SCENE (DES...| NO DEFECTS|                 DRY|   UNABLE TO DETERMINE|               W|     FLETCHER ST|     2137|           NO CONTROLS|             ONE-WAY|               CLEAR|                  NULL|              NULL|            Y|          NULL|              NULL|            NULL|       NULL|          NULL|             NULL|     NULL|2026-02-10 15:55:...|
# |                        9|STRAIGHT AND LEVEL|              2432|2026-02-06T17:37:...|                6|        17|          2|d42b8bf5633258973...|NO INJURY / DRIVE...|$501 - $1,500|2026-02-06T19:00:...|             UNKNOWN|             TURNING|             0|                      0|                     2|                          0|                            0|             0|               0|41.9983088064|DARKNESS, LIGHTED...|{"type": "Point",...|-87.6596963833|NO INDICATION OF ...|        2|                30|    UNABLE TO DETERMINE|NOT ON SCENE (DES...|    UNKNOWN|             UNKNOWN|   UNABLE TO DETERMINE|               N|     SHERIDAN RD|     6401|               UNKNOWN|      Y-INTERSECTION|               CLEAR|                     Y|              NULL|         NULL|          NULL|              NULL|            NULL|       NULL|          NULL|             NULL|     NULL|2026-02-10 15:55:...|
# |                       15|STRAIGHT AND LEVEL|              1914|2026-02-06T17:35:...|                6|        17|          2|61f6d1a6fb593e576...|NO INJURY / DRIVE...|$501 - $1,500|2026-02-06T17:35:...|         NO CONTROLS|SIDESWIPE OPPOSIT...|             0|                      0|                     4|                          0|                            0|             0|               0|41.9655338884|DARKNESS, LIGHTED...|{"type": "Point",...|-87.6554483784|NO INDICATION OF ...|        2|                15|   DRIVING SKILLS/KN...|            ON SCENE| NO DEFECTS|                 DRY|   UNABLE TO DETERMINE|               W|      WILSON AVE|     1014|           NO CONTROLS|         PARKING LOT|               CLEAR|                  NULL|                 N|         NULL|          NULL|                 Y|            NULL|       NULL|          NULL|             NULL|     NULL|2026-02-10 15:55:...|
# |                       48|STRAIGHT AND LEVEL|              1722|2026-02-06T17:32:...|                6|        17|          2|8670bd27ec69005c7...|NO INJURY / DRIVE...|$501 - $1,500|2026-02-06T17:39:...|FUNCTIONING PROPERLY|               ANGLE|             0|                      0|                     3|                          0|                            0|             0|               0|41.9681190568|            DARKNESS|{"type": "Point",...|-87.7291967855|NO INDICATION OF ...|        3|                15|   DRIVING SKILLS/KN...|            ON SCENE|    UNKNOWN|                 DRY|   UNABLE TO DETERMINE|               W|    LAWRENCE AVE|     4029|     STOP SIGN/FLASHER|            FOUR WAY|               CLEAR|                     Y|              NULL|         NULL|          NULL|              NULL|            NULL|       NULL|          NULL|             NULL|     NULL|2026-02-10 15:55:...|
# +-------------------------+------------------+------------------+--------------------+-----------------+----------+-----------+--------------------+--------------------+-------------+--------------------+--------------------+--------------------+--------------+-----------------------+----------------------+---------------------------+-----------------------------+--------------+----------------+-------------+--------------------+--------------------+--------------+--------------------+---------+------------------+-----------------------+--------------------+-----------+--------------------+----------------------+----------------+----------------+---------+----------------------+--------------------+--------------------+----------------------+------------------+-------------+--------------+------------------+----------------+-----------+--------------+-----------------+---------+--------------------+
# only showing top 20 rows
